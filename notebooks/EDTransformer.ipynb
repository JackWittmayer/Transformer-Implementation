# %% [markdown]
# <a href="https://colab.research.google.com/github/JackWittmayer/Transformer-Implementation/blob/main/EDTransformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
folder = "drive/MyDrive/colab data/Transformer-Implementation"

# %%
import sys
sys.path.insert(0, folder)

# %%
import torch
from torch.utils.data import DataLoader
from torch import nn

from src.model.encoder_decoder_transformer import EncoderDecoderTransformer
from src.training.trainer import train_model
from src.dataset.train_and_validation_sequence_datasets import (
    TrainAndValidationSequenceDatasets,
)
from src.dataset.pad_collate import PadCollate
from datetime import datetime

# %%
num_encoder_layers = 4
num_decoder_layers = 4
num_heads = 8
d_attn = 256
d_x = 256
d_z = 256
d_out = 256
d_mid = 256
d_mlp = 512
d_e = 256
max_sequence_length = 100
p_dropout = 0.1
vocab_size = 10000

if torch.cuda.is_available():
    device = torch.device("cuda")
else:
    device = torch.device("cpu")

enRawName = folder + "/multi30kEnAll.txt"
deRawName = folder + "/multi30kDeAll.txt"

# %%
saveDirectory = "./"
nameSuffix = ""
state_dict_filename = (
    saveDirectory
    + "encoder_decoder_transformer_state_dict_"
    + datetime.today().strftime("%Y-%m-%d %H")
    + nameSuffix
)

train_and_validation_sequence_datasets = TrainAndValidationSequenceDatasets(
    enRawName, deRawName, 0, 29000, 29000, 30014
)
custom_encoder_decoder_transformer = EncoderDecoderTransformer(
    num_encoder_layers,
    num_decoder_layers,
    num_heads,
    d_attn,
    d_x,
    d_z,
    d_out,
    d_mid,
    d_mlp,
    d_e,
    vocab_size,
    max_sequence_length,
    p_dropout,
    device
).to(device)
custom_encoder_decoder_transformer.src_embedding.table = custom_encoder_decoder_transformer.src_embedding.table.to(device)
custom_encoder_decoder_transformer.tgt_embedding.table = custom_encoder_decoder_transformer.tgt_embedding.table.to(device)
custom_encoder_decoder_transformer.positionalEmbedding.table = custom_encoder_decoder_transformer.positionalEmbedding.table.to(device)
train_dataset = train_and_validation_sequence_datasets.train_dataset
val_dataset = train_and_validation_sequence_datasets.val_dataset
pad_collate = PadCollate(enRawName, deRawName, vocab_size, vocab_size)
train_dataloader = DataLoader(train_dataset, batch_size=256, collate_fn=pad_collate)
val_dataloader = DataLoader(val_dataset, batch_size=256, collate_fn=pad_collate)
train_model(
    custom_encoder_decoder_transformer,
    train_dataloader,
    val_dataloader,
    pad_collate.tgt_tokenizer,
    device,
    state_dict_filename
)
# Out:
# creating tokenizer for drive/MyDrive/colab data/Transformer-Implementation/multi30kEnAll.txt
# creating tokenizer for drive/MyDrive/colab data/Transformer-Implementation/multi30kDeAll.txt
# <generator object Module.parameters at 0x77fd3c454dd0>
# Completed training step 0
# Completed training step 20
# Completed training step 40
# Completed training step 60
# Completed training step 80
# Completed training step 100
# Completed validation step 0
# epoch 0 took 21.499788284301758
# avg training loss: 7.658419458489669
# avg validation loss: 6.705053806304932
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [109, 124, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 1, 14, 1, 14, 14, 14, 1, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Ein Mann und und und und und und und und und und und und und und . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 119, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 114, 14, 114, 1, 14, 1, 1, 1, 14, 14, 1, 1, 14, 14, 14, 14, 14, 1, 1, 14, 14, 14, 1, 14, 114]
# decoded validation output: Ein Mann mit und und und und und und und und und und und und und und . und . . . . . . . . . . . . und
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 120
# Completed training step 140
# Completed training step 160
# Completed training step 180
# Completed training step 200
# Completed training step 220
# epoch 1 took 20.96952247619629
# avg training loss: 6.237990709773281
# avg validation loss: 6.162376642227173
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [109, 124, 100, 111, 100, 111, 111, 111, 111, 12, 12, 111, 114, 111, 111, 111, 12, 14, 111, 14, 12, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 12, 14, 14]
# decoded train output: Ein Mann in einem in einem einem einem einem , , einem und einem einem einem , . einem . , . . . . . . . . . . . . . . . . . . . . . . . , . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 111, 111, 111, 114, 114, 111, 114, 111, 114, 111, 114, 12, 111, 114, 114, 1, 14, 14, 14, 114, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 114, 114]
# decoded validation output: Ein Mann in einem einem einem einem und und einem und einem und einem und , einem und und . . . und . . . . . . . . . . . . . . . und und
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 240
# Completed training step 260
# Completed training step 280
# Completed training step 300
# Completed training step 320
# Completed training step 340
# epoch 2 took 21.29692578315735
# avg training loss: 5.797551820152684
# avg validation loss: 5.8702720403671265
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [109, 124, 100, 100, 114, 100, 111, 12, 111, 14, 14, 12, 12, 12, 111, 111, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 1, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Ein Mann in in und in einem , einem . . , , , einem einem . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 114, 114, 114, 114, 114, 114, 114, 111, 14, 114, 111, 14, 114, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14]
# decoded validation output: Ein Mann in einem und und und und und und und einem . und einem . und . . . . . . . . . . . . . . . . . . . . . .
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 360
# Completed training step 380
# Completed training step 400
# Completed training step 420
# Completed training step 440
# epoch 3 took 21.434706211090088
# avg training loss: 5.510139477880378
# avg validation loss: 5.62504506111145
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 217, 100, 12, 14, 12, 111, 12, 111, 14, 14, 12, 12, 12, 111, 12, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Männer in , . , einem , einem . . , , , einem , . . . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 276, 114, 276, 114, 114, 114, 100, 111, 276, 12, 111, 276, 12, 276, 12, 1, 14, 12, 14, 14, 114, 14, 12, 14, 12, 12, 124, 12, 14, 124, 14, 12, 124, 12, 124, 114, 12]
# decoded validation output: Ein Mann in einem blauen und blauen und und und in einem blauen , einem blauen , blauen , . , . . und . , . , , Mann , . Mann . , Mann , Mann und ,
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 460
# Completed training step 480
# Completed training step 500
# Completed training step 520
# Completed training step 540
# Completed training step 560
# epoch 4 took 21.936248064041138
# avg training loss: 5.263725690674364
# avg validation loss: 5.408792972564697
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 217, 100, 12, 244, 12, 103, 12, 111, 244, 12, 137, 12, 12, 111, 152, 14, 14, 137, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Männer in , Straße , ein , einem Straße , Frau , , einem die . . Frau . . . . . . . . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 266, 114, 266, 114, 266, 100, 100, 111, 276, 114, 111, 280, 114, 280, 114, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 114, 14, 14, 280, 14, 1, 14, 14, 114, 114]
# decoded validation output: Ein Mann in einem Hemd und Hemd und Hemd in in einem blauen und einem weißen und weißen und . . . . . . . . . . . und . . weißen . . . und und
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 580
# Completed training step 600
# Completed training step 620
# Completed training step 640
# Completed training step 660
# Completed training step 680
# Completed validation step 20
# epoch 5 took 21.5469331741333
# avg training loss: 5.082123501258984
# avg validation loss: 5.269282817840576
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 217, 100, 117, 244, 12, 152, 12, 111, 244, 12, 12, 12, 12, 121, 12, 14, 244, 137, 12, 12, 12, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei
 14, 14, 14, 14, 14, 14, 153, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen mit etwas anderen te etwas , , , während anderen anderen Personen zu sie zu sind zu . . . . . . . . . . . . . . zu . . . . . . zu . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 13, 393, 230, 117, 111, 975, 114, 111, 975, 13, 975, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14]
# decoded validation output: Ein Mann in einem roten - weißen - Oberteil sitzt auf einem Stuhl und einem Stuhl - Stuhl . . . . . . . . . . . . . . . . . . . . .
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2400
# Completed training step 2420
# Completed training step 2440
# Completed training step 2460
# Completed training step 2480
# Completed training step 2500
# epoch 21 took 24.111149549484253
# avg training loss: 3.3709185939086113
# avg validation loss: 3.829260766506195
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 12, 588, 119, 586, 722, 138, 571, 12, 12, 12, 152, 343, 458, 269, 153, 343, 153, 153, 153, 443, 14, 14, 1, 153, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 153, 14, 14, 14, 14, 14, 14, 153, 14, 1]
# decoded train output: Zwei Frauen stehen draußen Freien , schauen mit ihren Gesicht te ihre , , , die sie anderen Personen zu sie zu zu zu sind . . zu . . . . . . . . . . zu . . . . . . zu .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 13, 266, 230, 117, 111, 975, 117, 111, 975, 114, 975, 114, 1, 14, 14, 49, 14, 14, 14, 14, 14, 266, 1392, 14, 14, 14, 266, 975, 14, 975, 14, 14, 106, 975]
# decoded validation output: Ein Mann in einem roten - weißen - Hemd sitzt auf einem Stuhl auf einem Stuhl und Stuhl und . . T . . . . . Hemd Computer . . . Hemd Stuhl . Stuhl . . an Stuhl
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2520
# Completed training step 2540
# Completed training step 2560
# Completed training step 2580
# Completed training step 2600
# Completed training step 2620
# epoch 22 took 24.2957603931427
# avg training loss: 3.3092730672735917
# avg validation loss: 3.7671828866004944
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 119, 588, 119, 111, 2020, 133, 722, 119, 12, 12, 248, 458, 458, 269, 185, 107, 153, 153, 153, 448, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 1, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien mit schauen mit einem Kuchen ten Gesicht mit , , während anderen anderen Personen um eine zu zu zu sehen . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 13, 940, 114, 117, 111, 975, 114, 111, 975, 13, 975, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 975]
# decoded validation output: Ein Mann in einem roten - weißen - gestreiften und auf einem Stuhl und einem Stuhl - Stuhl . . . . . . . . . . . . . . . . . . . . . Stuhl
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2640
# Completed training step 2660
# Completed training step 2680
# Completed training step 2700
# Completed training step 2720
# epoch 23 took 24.484835624694824
# avg training loss: 3.253381701937893
# avg validation loss: 3.7005314230918884
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 871, 119, 586, 660, 133, 660, 12, 12, 12, 248, 185, 458, 269, 153, 343, 153, 153, 153, 14, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien und essen mit ihren Essen ten Essen , , , während um anderen Personen zu sie zu zu zu . . . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 13, 49, 230, 117, 111, 975, 114, 111, 975, 13, 975, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 1, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded validation output: Ein Mann in einem roten - weißen - T sitzt auf einem Stuhl und einem Stuhl - Stuhl . . . . . . . . . . . . . . . . . . . .
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2740
# Completed training step 2760
# Completed training step 2780
# Completed training step 2800
# Completed training step 2820
# Completed training step 2840
# epoch 24 took 23.289279222488403
# avg training loss: 3.1935798724492392
# avg validation loss: 3.6406227350234985
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 119, 588, 119, 111, 722, 138, 398, 571, 106, 152, 152, 488, 458, 269, 185, 343, 153, 14, 153, 343, 153, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien mit schauen mit einem Gesicht te etwas ihre an die die andere anderen Personen um sie zu . zu sie zu . . . . . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 940, 266, 230, 117, 111, 975, 106, 111, 975, 14, 975, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 975]
# decoded validation output: Ein Mann in einem roten - weißen gestreiften Hemd sitzt auf einem Stuhl an einem Stuhl . Stuhl . . . . . . . . . . . . . . . . . . . . . Stuhl
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2860
# Completed training step 2880
# Completed training step 2900
# Completed training step 2920
# Completed training step 2940
# Completed training step 2960
# Completed validation step 100
# epoch 25 took 21.399924516677856
# avg training loss: 3.1390841467338695
# avg validation loss: 3.6231048703193665
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 588, 398, 111, 196, 75, 398, 176, 106, 12, 152, 488, 458, 269, 153, 343, 153, 153, 153, 153, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 153, 14, 14, 14, 14, 14, 14, 153, 153, 14]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen etwas einem Mädchen s etwas sich an , die andere anderen Personen zu sie zu zu zu zu . . . . . . . . . . . . . zu . . . . . . zu zu .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 940, 940, 230, 117, 111, 975, 114, 111, 975, 14, 975, 14, 1, 14, 14, 1846, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14, 14, 14]
# decoded validation output: Ein Mann in einem roten - weißen gestreiften gestreiften sitzt auf einem Stuhl und einem Stuhl . Stuhl . . . boden . . . . . . . . . . . . . . . . .
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 2980
# Completed training step 3000
# Completed training step 3020
# Completed training step 3040
# Completed training step 3060
# epoch 26 took 21.710729122161865
# avg training loss: 3.088576638907717
# avg validation loss: 3.617358386516571
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 588, 119, 111, 2020, 133, 2020, 117, 117, 150, 185, 571, 458, 269, 185, 343, 185, 446, 185, 1050, 446, 14, 1, 14, 14, 14, 14, 14, 14, 1, 14, 1, 14, 14, 590, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen mit einem Kuchen ten Kuchen auf auf den um ihre anderen Personen um sie um hat um haben hat . . . . . . . . . . herum . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13, 280, 13, 1366, 114, 117, 111, 975, 114, 111, 975, 13, 2089, 114, 1, 13, 14, 75, 14, 14, 14, 14, 75, 14, 471, 1, 1, 14, 497, 1, 924, 1252, 14, 14, 471, 266]
# decoded validation output: Ein Mann in einem roten - weißen - Hemden und auf einem Stuhl und einem Stuhl - Schreibtisch und - . s . . . . s . vorbei . Gebäude stand Papier . . vorbei Hemd
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 3080
# Completed training step 3100
# Completed training step 3120
# Completed training step 3140
# Completed training step 3160
# Completed training step 3180
# epoch 27 took 21.804174423217773
# avg training loss: 3.0414216372004725
# avg validation loss: 3.59041291475296
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 588, 398, 586, 684, 138, 458, 117, 153, 12, 185, 343, 1140, 269, 185, 343, 153, 153, 153, 1050, 14, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 153, 14, 14, 14, 14, 14, 14, 14, 14, 14]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen etwas ihren Baseball te anderen auf zu , um sie Rücken Personen um sie zu zu zu haben . . . . . . . . . . . . . zu . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 614, 13, 280, 940, 940, 230, 117, 111, 975, 106, 111, 975, 13, 1062, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 975]
# decoded validation output: Ein Mann in einem rot - weißen gestreiften gestreiften sitzt auf einem Stuhl an einem Stuhl - Seil . . . . . . . . . . . . . . . . . . . . . Stuhl
# Saved model state dict to ./encoder_decoder_transformer_state_dict_2024-08-14 14
#
#
# Completed training step 3200
# Completed training step 3220
# Completed training step 3240
# Completed training step 3260
# Completed training step 3280
# Completed training step 3300
# epoch 28 took 21.36488127708435
# avg training loss: 2.999972609051487
# avg validation loss: 3.5143511295318604
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 588, 117, 586, 2666, 76, 2666, 117, 117, 586, 152, 488, 458, 458, 153, 343, 153, 153, 153, 961, 14, 14, 1, 14, 14, 14, 14, 14, 14, 1, 1, 1, 14, 14, 153, 14, 14, 1, 14, 14, 14, 14, 14, 1]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen auf ihren Teller t Teller auf auf ihren die andere anderen anderen zu sie zu zu zu werden . . . . . . . . . . zu . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 294, 13,
 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen mit etwas Kuchen te Kuchen etwas an , während sie anderen Personen um sie zu zu zu haben haben . . . . . . . . . . . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 614, 614, 13, 322, 940, 393, 230, 117, 111, 975, 106, 111, 975, 13, 1392, 14, 1, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 14, 1, 14, 14]
# decoded validation output: Ein Mann in rot rot - weiß gestreiften Oberteil sitzt auf einem Stuhl an einem Stuhl - Computer . . . . . . . . . . . . . . . . . . . . .
# Average validation loss did not decrease from  3.4336702823638916
# Failed to decrease the average validation loss 1 times.
#
#
# Completed training step 3780
# Completed training step 3800
# Completed training step 3820
# Completed training step 3840
# Completed training step 3860
# epoch 33 took 21.849695205688477
# avg training loss: 2.7793771321313425
# avg validation loss: 3.4856433272361755
# expected train output Zwei Frauen stehen im Freien und blicken mit einem kom ischen Gesichtsausdruck etwas an , das den anderen Personen um sie herum nicht aufzu fallen scheint .
# argmax x: [160, 289, 281, 633, 459, 114, 588, 119, 111, 2020, 138, 2020, 117, 12, 12, 185, 152, 458, 269, 185, 343, 185, 446, 590, 466, 446, 14, 1, 14, 14, 14, 14, 14, 14, 1, 1, 1, 14, 14, 153, 14, 14, 14, 14, 14, 14, 14, 14, 1]
# decoded train output: Zwei Frauen stehen draußen Freien und schauen mit einem Kuchen te Kuchen auf , , um die anderen Personen um sie um hat herum halten hat . . . . . . . . . zu . . . . . . . .
# expected validation output Ein Mann in einem rot - weiß gestreiften Hemd sitzt auf einem Hocker an einem Hotdog - Stand .
# argmax x: [109, 124, 100, 111, 614, 13, 322, 940, 1366, 230, 117, 111, 975, 114, 111, 975, 13, 3339, 114, 1, 14, 1383, 1846, 1383, 14, 14, 14, 75, 14, 924, 14, 14, 14, 14, 221, 14, 1383, 221, 14, 1383, 1846]
# decoded validation output: Ein Mann in einem rot - weiß gestreiften Hemden sitzt auf einem Stuhl und einem Stuhl - Hammer und . stuhl boden stuhl . . . s . stand . . . . steht . stuhl steht . stuhl boden
# Average validation loss did not decrease from  3.4336702823638916
# Failed to decrease the average validation loss 2 times.
# Stopping training

# %%
model = EncoderDecoderTransformer(num_encoder_layers, num_decoder_layers, num_heads, d_attn, d_x, d_z, d_out, d_mid, d_mlp, d_e, vocab_size, max_sequence_length, p_dropout, device).to(device)
state_dict_filename = "/content/encoder_decoder_transformer_state_dict_2024-08-14 14"
state_dict = torch.load(state_dict_filename, map_location = device)
model.load_state_dict(state_dict)
# Out:
# <All keys matched successfully>

# %%
def predict_from_tokens(model, input, src_tokenizer, tgt_tokenizer):
    model.disable_subsequent_mask()
    src_tokenizer.no_padding()
    tgt_tokenizer.no_padding()

    src_tokenizer.no_truncation()
    tgt_tokenizer.no_truncation()
    src_sequence = input
    print(src_sequence)
    src_sequence = src_tokenizer.encode(src_sequence)
    print(src_sequence)
    print(src_tokenizer.decode(src_sequence.ids))
    src_sequence = torch.IntTensor(src_sequence.ids).unsqueeze(0).to(device)
    print("src tokens", src_sequence)
    tgt_sequence = torch.IntTensor([0]).unsqueeze(0).to(device)
    src_mask = torch.ones(src_sequence.shape, dtype=torch.int32).to(device)
    print("decoder input", tgt_sequence)
    predictions = []
    with torch.no_grad():
        model.eval()
        length_gen = 100
        for i in range(length_gen):
            tgt_mask = torch.ones(tgt_sequence.shape, dtype=torch.int32).to(device)
            prediction = model(src_sequence, tgt_sequence, src_mask, tgt_mask)
            prediction = torch.softmax(prediction, -1)
            prediction = torch.argmax(prediction, dim=-1)
            print("argmax prediction:", prediction)
            print("actual prediction:", tgt_tokenizer.decode(prediction[0].tolist()))
            last_token = prediction[0][-1]
            tgt_sequence = torch.cat((tgt_sequence, last_token.unsqueeze(0).unsqueeze(0)), dim=-1)
            if last_token == 1:
                break
    return tgt_sequence

pad_collate = PadCollate(enRawName, deRawName, vocab_size, vocab_size)
tgt_sequence = predict_from_tokens(model, "A man eats an apple in the park.", pad_collate.src_tokenizer, pad_collate.tgt_tokenizer)
print(tgt_sequence)
print(pad_collate.tgt_tokenizer.decode(tgt_sequence[0].tolist()))
# Out:
# creating tokenizer for drive/MyDrive/colab data/Transformer-Implementation/multi30kEnAll.txt
# creating tokenizer for drive/MyDrive/colab data/Transformer-Implementation/multi30kDeAll.txt
# A man eats an apple in the park.
# Encoding(num_tokens=9, attributes=[ids, type_ids, tokens, offsets, attention_mask, special_tokens_mask, overflowing])
# A man eats an apple in the park .
# src tokens tensor([[  30,   93, 2354,   84, 2933,   83,   94,  411,   15]],
#        device='cuda:0', dtype=torch.int32)
# decoder input tensor([[0]], device='cuda:0', dtype=torch.int32)
# argmax prediction: tensor([[109]], device='cuda:0')
# actual prediction: Ein
# argmax prediction: tensor([[124, 124]], device='cuda:0')
# actual prediction: Mann Mann
# argmax prediction: tensor([[898, 124, 898]], device='cuda:0')
# actual prediction: isst Mann isst
# argmax prediction: tensor([[898, 124, 148, 100]], device='cuda:0')
# actual prediction: isst Mann im in
# argmax prediction: tensor([[898, 124, 148, 144, 111]], device='cuda:0')
# actual prediction: isst Mann im einen einem
# argmax prediction: tensor([[898, 124, 148, 144, 111, 532]], device='cuda:0')
# actual prediction: isst Mann im einen einem Park
# argmax prediction: tensor([[898, 124, 148, 144, 111, 532, 144]], device='cuda:0')
# actual prediction: isst Mann im einen einem Park einen
# argmax prediction: tensor([[ 898,  124,  148,  144,  111,  532,  103, 4721]], device='cuda:0')
# actual prediction: isst Mann im einen einem Park ein Apfel
# argmax prediction: tensor([[   1,  124,  148,  144,  111,  532,  273, 4721,  148]],
#        device='cuda:0')
# actual prediction: Mann im einen einem Park das Apfel im
# argmax prediction: tensor([[   1,    1,    1,  144,  121, 4721,  103,    1,   14,  532]],
#        device='cuda:0')
# actual prediction: einen der Apfel ein . Park
# argmax prediction: tensor([[  1,   1,   1, 103, 111,   1,  14,   1,  14,   1,  14]],
#        device='cuda:0')
# actual prediction: ein einem . . .
# argmax prediction: tensor([[  1,   1,   1, 103, 111,   1,  14,   1,  14,   1,  14,   1]],
#        device='cuda:0')
# actual prediction: ein einem . . .
# tensor([[   0,  109,  124,  898,  100,  111,  532,  144, 4721,  148,  532,   14,
#             1]], device='cuda:0')
# Ein Mann isst in einem Park einen Apfel im Park .
